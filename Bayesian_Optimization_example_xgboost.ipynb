# %%
import pandas as pd

# %%
from bayes_opt import BayesianOptimization
from sklearn.model_selection import cross_val_score

# %%
#Cross-validation version

def XGBcv(max_depth, min_child_weight, max_delta_step, subsample,
          scale_pos_weight):
    max_depth = int(max_depth)
    learning_rate =  0.1
        # Use the line below for classification
        # DO NOT use the line below when doing classification
    subsample= subsample
    colsample_bytree = 0.2
    min_child_weight=int(min_child_weight)
    max_delta_step=int(max_delta_step)
    scale_pos_weight = int(scale_pos_weight)

    # Use 10-fold validation if you have time to spare
    #folds = 10
    folds=1
    cv_score = 0

    print(" Search parameters (%d-fold validation):\n " % (folds),file=log_file)
    log_file.flush()

    # Do not optimize the number of boosting rounds, as early stopping will take care of that

    
    xgb_model = XGBClassifier(seed=101,learning_rate=learning_rate, n_estimators=n_estimators,
                    min_child_weight=min_child_weight, max_depth=max_depth,
                    colsample_bytree=colsample_bytree, subsample=subsample,scale_pos_weight= scale_pos_weight,early_stopping_rounds = 50,nthread = -1)
    
    eval_metrics = ['auc','map']
    eval_sets = [(X_test ,y_test)]

    xgb = xgb_model.fit(X_train, y_train,eval_metric=eval_metrics, eval_set=eval_sets,early_stopping_rounds = 50 , verbose=False)
        
    scores = cross_val_score(xgb_model, X_train,y_train, cv=TimeSeriesSplit(5),scoring = 'average_precision') # Can use stratified cross-validation or kfold cross-validation over here as well.

# All relevant things in XGboost output are in stdout, so we screen result[1]
# for a line with "cv-mean". This line signifies the end of output and contains CV values.
# Next we split the line to extract CV values. We also print the whole CV run into file
# In previous XGboost the output was in stderr, in which case we would need result[0]


    cv_score = sum(scores)/5

    # The CV metrics function in XGboost can be lots of things. Some of them need to be maximized, like AUC.
    # If the metrics needs to be minimized, e.g, logloss, the return line below should be a negative number
    # as Bayesian Optimizer only knows how to maximize the function
    print(cv_score)
    return (cv_score)
 #return cv_score

# %%
import contextlib


@contextlib.contextmanager
def capture():
    import sys
    from io import StringIO
    olderr, oldout = sys.stderr, sys.stdout
    try:
        out = [StringIO(), StringIO()]
        sys.stderr, sys.stdout = out
        yield out
    finally:
        sys.stderr, sys.stdout = olderr, oldout
        out[0] = out[0].getvalue().splitlines()
        out[1] = out[1].getvalue().splitlines()

# %%
from xgboost import XGBClassifier

log_file = open("XGBoost_output_file1.txt", 'a')


print('\n', file=log_file)
log_file.flush()

print('Running Bayesian Optimization ...\n')
XGB_BOpt.maximize(init_points=5, n_iter=100)
# Production parameters
#XG_BOpt.maximize(init_points=5, n_iter=50)

print('\nFinal Results')
print('XGBOOST: %f' % XGB_BOpt.res['max']['max_val'])
print('\nFinal Results', file=log_file)
print('XGBOOST: %f' % XGB_BOpt.res['max']['max_val'], file=log_file)
log_file.flush()
log_file.close()

# %% [markdown]
# Sample Output
#
# Running Bayesian Optimization ...
#
# Initialization
# -------------------------------------------------------------------------------------------------------------------------------------------
#  Step |   Time |      Value |   colsample_bytree |   max_delta_step |   max_depth |   min_child_weight |   scale_pos_weight |   subsample |
# 0.350312
#     1 | 16m30s |    0.35031 |             0.7092 |           1.8173 |     14.9005 |             3.7998 |            61.1374 |      0.8727 |
# 0.34881
#     2 | 12m42s |    0.34881 |             0.6211 |           3.6932 |      3.1668 |             3.0246 |            25.6641 |      0.4797 |
# 0.3235
#     3 | 06m57s |    0.32350 |             0.2881 |           3.1624 |      7.4868 |             4.2983 |           188.8965 |      0.5480 |
# 0.326527
#     4 | 07m15s |    0.32653 |             0.2390 |           3.6816 |     12.9815 |             7.2045 |           127.3903 |      0.8959 |
# 0.313646
#     5 | 08m49s |    0.31365 |             0.8987 |           3.0033 |      7.3654 |            19.4610 |           124.6823 |      0.2077 |
# Bayesian Optimization
# -------------------------------------------------------------------------------------------------------------------------------------------
#  Step |   Time |      Value |   colsample_bytree |   max_delta_step |   max_depth |   min_child_weight |   scale_pos_weight |   subsample |
# 0.242235
#     6 | 15m09s |    0.24224 |             0.5549 |           1.6748 |     14.7514 |             1.7931 |           299.8931 |      0.6948 |
# 0.322571
#     7 | 12m25s |    0.32257 |             0.4895 |           0.4034 |     14.7531 |             2.2392 |             1.6148 |      0.2964 |
# 0.369108
#     8 | 12m09s |    0.36911 |             0.7579 |           0.6139 |      3.2008 |             1.3492 |            78.8463 |      0.4648 |
# 0.349655
#     9 | 06m09s |    0.34965 |             0.2986 |           4.6954 |      3.1508 |             1.4186 |            72.8404 |      0.9643 |
# 0.339869
#    10 | 07m25s |    0.33987 |             0.2848 |           0.1495 |      3.2461 |             2.1970 |            48.6964 |      0.4144 |
# 0.355715
#    11 | 12m33s |    0.35572 |             0.9680 |           0.3275 |      3.2745 |            19.9601 |             5.1760 |      0.6673 |
# 0.305993
#    12 | 10m25s |    0.30599 |             0.4411 |           0.1758 |     14.1587 |            19.9856 |           230.9389 |      0.4414 |
# 0.328866
#    13 | 09m48s |    0.32887 |             0.5409 |           0.0906 |     13.2816 |            19.7332 |            81.7352 |      0.2381 |
# 0.342742
#    14 | 05m47s |    0.34274 |             0.3174 |           0.4645 |      3.2360 |             1.5255 |           237.5188 |      0.8931 |
# 0.322878
#    15 | 10m39s |    0.32288 |             0.6725 |           0.1486 |      3.9220 |             1.3059 |           104.9258 |      0.7049 |
# 0.227901
#    16 | 12m15s |    0.22790 |             0.5159 |           0.0000 |     13.9839 |             1.0498 |           217.0310 |      0.5485 |
# 0.329659
#    17 | 09m16s |    0.32966 |             1.0000 |           5.0000 |      3.0000 |            20.0000 |           278.7430 |      0.3534 |
# 0.299185
#    18 | 05m37s |    0.29918 |             0.2000 |           0.0000 |      3.0000 |            20.0000 |           169.2183 |      0.2000 |
# 0.420303
#    19 | 23m17s |    0.42030 |             1.0000 |           0.0000 |     15.0000 |            20.0000 |            31.3184 |      1.0000 |
# 0.40177
#    20 | 21m52s |    0.40177 |             1.0000 |           5.0000 |     15.0000 |            19.9933 |            17.9945 |      0.5271 |
# 0.341428
#    21 | 25m37s |    0.34143 |             1.0000 |           5.0000 |      3.0000 |            20.0000 |           227.7029 |      1.0000 |
# 0.338041
#    22 | 21m28s |    0.33804 |             1.0000 |           5.0000 |     15.0000 |            20.0000 |            36.1704 |      0.2000 |
# 0.355003
#    23 | 07m51s |    0.35500 |             0.2000 |           5.0000 |      3.0000 |             1.0000 |           264.0092 |      1.0000 |
# 0.421183
#    24 | 08m44s |    0.42118 |             0.2000 |           0.0444 |     14.9930 |            18.0620 |            17.9121 |      1.0000 |
# 0.305571
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([  1.64490874e-05]), 'nit': 6, 'warnflag': 2, 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 53}
#   " state: %s" % convergence_dict)
#    25 | 15m47s |    0.30557 |             1.0000 |           0.0000 |      3.0000 |             1.0000 |           148.2388 |      1.0000 |
# 0.310162
#    26 | 07m55s |    0.31016 |             0.4740 |           0.0000 |      3.0000 |            20.0000 |           257.1546 |      0.2776 |
# 0.387093
#    27 | 10m10s |    0.38709 |             0.6196 |           0.3227 |      4.8003 |            19.7253 |            24.0585 |      0.8621 |
# 0.364258
#    28 | 11m22s |    0.36426 |             0.3943 |           0.0936 |     14.9297 |             2.5087 |            28.0710 |      0.7828 |
# 0.395623
#    29 | 17m37s |    0.39562 |             0.7714 |           0.3661 |     14.4511 |            19.5466 |             1.3855 |      0.7250 |
# 0.345654
#    30 | 07m10s |    0.34565 |             0.2000 |           5.0000 |      3.0000 |            20.0000 |           300.0000 |      1.0000 |
# 0.340106
#    31 | 18m13s |    0.34011 |             0.8159 |           0.0971 |     14.4905 |             1.0094 |            88.1993 |      0.7682 |
# 0.388454
#    32 | 18m44s |    0.38845 |             0.9073 |           0.4668 |     14.9156 |            19.1656 |            20.4545 |      0.3987 |
# 0.363001
#    33 | 08m08s |    0.36300 |             0.2000 |           0.0000 |      3.0000 |            20.0000 |           201.3177 |      1.0000 |
# 0.369051
#    34 | 08m14s |    0.36905 |             0.2000 |           5.0000 |     15.0000 |            20.0000 |           189.2141 |      1.0000 |
# 0.331113
#    35 | 05m49s |    0.33111 |             0.2000 |           0.0000 |      3.0000 |             1.0000 |           300.0000 |      1.0000 |
# 0.32721
#    36 | 07m56s |    0.32721 |             0.6577 |           0.0870 |      3.0221 |            19.5187 |            58.6750 |      0.8738 |
# 0.356396
#    37 | 08m30s |    0.35640 |             0.2000 |           0.0000 |     15.0000 |            18.2754 |           143.6408 |      1.0000 |
# 0.440482
#    38 | 11m34s |    0.44048 |             0.3008 |           4.9888 |     14.9346 |            19.3951 |             7.3177 |      0.8373 |
# 0.444346
#    39 | 10m43s |    0.44435 |             0.2000 |           5.0000 |     15.0000 |            10.6853 |            11.7697 |      1.0000 |
# 0.448839
#    40 | 13m23s |    0.44884 |             0.2880 |           4.9316 |     14.8565 |            16.4402 |            10.1248 |      0.9977 |
# 0.449974
#    41 | 12m22s |    0.44997 |             0.2707 |           4.8985 |     11.1118 |            14.0688 |             7.1978 |      0.9989 |
# 0.433249
#    42 | 12m42s |    0.43325 |             0.3995 |           4.6643 |      8.4202 |            12.7332 |            13.4043 |      0.9875 |
# 0.436684
#    43 | 13m37s |    0.43668 |             0.2912 |           4.9465 |     14.1654 |            17.0072 |             2.6185 |      0.9190 |
# 0.441198
#    44 | 11m14s |    0.44120 |             0.2360 |           3.7692 |     12.9212 |            14.3537 |            10.9476 |      0.9992 |
# 0.448973
#    45 | 08m01s |    0.44897 |             0.2118 |           4.9224 |      8.4476 |            10.9733 |             3.7438 |      0.9237 |
# 0.421655
#    46 | 08m33s |    0.42166 |             0.2089 |           4.8152 |      5.1262 |             7.9474 |             3.0171 |      0.9845 |
# 0.41893
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ -8.98664039e-05]), 'nit': 4, 'warnflag': 2, 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 47}
#   " state: %s" % convergence_dict)
#    47 | 15m00s |    0.41893 |             0.3868 |           4.3227 |     13.9849 |            11.2007 |             6.6575 |      0.9494 |
# 0.273742
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([  8.69235363e-05]), 'nit': 5, 'warnflag': 2, 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 49}
#   " state: %s" % convergence_dict)
#    48 | 12m53s |    0.27374 |             0.4015 |           2.0988 |     14.9042 |             1.1672 |           167.1098 |      0.7626 |
# 0.427928
#    49 | 11m50s |    0.42793 |             0.3566 |           4.7718 |      8.9208 |            19.7573 |             1.8227 |      0.9758 |
# 0.368296
#    50 | 08m22s |    0.36830 |             0.2000 |           0.0000 |     14.7497 |            18.6400 |           112.9926 |      1.0000 |
# 0.431453
#    51 | 14m20s |    0.43145 |             0.3728 |           4.8485 |     14.2829 |            11.4971 |            17.1965 |      0.9776 |
# 0.474122
#    52 | 09m16s |    0.47412 |             0.2926 |           4.9621 |      7.7657 |            10.8566 |             8.0018 |      0.9341 |
# 0.34308
#    53 | 07m11s |    0.34308 |             0.2000 |           0.0000 |      3.0000 |             1.0000 |           280.3806 |      1.0000 |
# 0.386503
#    54 | 07m14s |    0.38650 |             0.2326 |           4.2751 |      3.4972 |            10.2799 |             8.3143 |      0.9265 |
# 0.250103
#    55 | 24m18s |    0.25010 |             1.0000 |           5.0000 |     15.0000 |             1.0000 |           250.6218 |      1.0000 |
# 0.345403
#    56 | 11m22s |    0.34540 |             0.7082 |           4.3755 |      3.3654 |            19.6289 |            95.3896 |      0.9413 |
# 0.365794
#    57 | 07m53s |    0.36579 |             0.2000 |           5.0000 |     15.0000 |            20.0000 |           208.8201 |      1.0000 |
# 0.337831
#    58 | 08m22s |    0.33783 |             0.2000 |           5.0000 |     15.0000 |            20.0000 |           158.7400 |      1.0000 |
# 0.403508
#    59 | 13m25s |    0.40351 |             0.4281 |           4.8259 |      9.1750 |             1.0461 |            10.3377 |      0.7107 |
# 0.339917
#    60 | 25m58s |    0.33992 |             1.0000 |           5.0000 |      3.0000 |            20.0000 |           188.1072 |      1.0000 |
# 0.35897
#    61 | 08m10s |    0.35897 |             0.2000 |           0.0000 |     15.0000 |            20.0000 |           300.0000 |      1.0000 |
# 0.378017
#    62 | 08m21s |    0.37802 |             0.2000 |           0.0000 |     15.0000 |            20.0000 |           277.1276 |      1.0000 |
# 0.350984
#    63 | 11m43s |    0.35098 |             0.2000 |           0.0000 |      3.0000 |            20.0000 |           290.6104 |      1.0000 |
# 0.396596
#    64 | 08m59s |    0.39660 |             0.3784 |           0.0667 |      5.2047 |            19.2892 |            38.4570 |      0.8584 |
# 0.33806
#    65 | 08m45s |    0.33806 |             0.2000 |           5.0000 |      3.0000 |             1.0000 |           208.3527 |      1.0000 |
# 0.445115
#    66 | 34m59s |    0.44511 |             0.9717 |           4.9223 |      8.9501 |             8.7032 |             7.7729 |      0.9501 |
# 0.356884
#    67 | 09m12s |    0.35688 |             0.2000 |           5.0000 |     15.0000 |            20.0000 |           288.2211 |      1.0000 |
# 0.382539
#    68 | 08m15s |    0.38254 |             0.2814 |           4.7818 |      8.2451 |            11.6532 |             7.6405 |      0.3924 |
# 0.370668
#    69 | 07m26s |    0.37067 |             0.2000 |           5.0000 |      3.0000 |            20.0000 |           146.1644 |      1.0000 |
# 0.327438
#    70 | 09m01s |    0.32744 |             0.2000 |           5.0000 |     15.0000 |             1.0000 |            42.2186 |      1.0000 |
# 0.281299
#    71 | 24m39s |    0.28130 |             1.0000 |           5.0000 |     15.0000 |             1.0000 |           108.7169 |      1.0000 |
# 0.356891
#    72 | 08m14s |    0.35689 |             0.2000 |           5.0000 |     15.0000 |            20.0000 |           257.2982 |      1.0000 |
# 0.386361
#    73 | 09m23s |    0.38636 |             0.2000 |           0.0000 |     15.0000 |            20.0000 |            53.1350 |      1.0000 |
# 0.370921
#    74 | 11m21s |    0.37092 |             0.2000 |           5.0000 |      3.0000 |             1.0000 |           170.9891 |      1.0000 |
# 0.369537
#    75 | 08m45s |    0.36954 |             0.2000 |           5.0000 |     15.0000 |            20.0000 |            98.6936 |      1.0000 |
# 0.251817
#    76 | 09m35s |    0.25182 |             0.2000 |           5.0000 |     15.0000 |             1.0000 |           144.4107 |      1.0000 |
# 0.35491
#    77 | 06m55s |    0.35491 |             0.2000 |           0.0000 |      3.0000 |             1.0000 |           125.8445 |      1.0000 |
# 0.163913
#    78 | 06m08s |    0.16391 |             0.2000 |           0.0000 |     15.0000 |             1.0000 |           270.5580 |      0.2000 |
# 0.380841
#    79 | 08m07s |    0.38084 |             0.2000 |           5.0000 |     15.0000 |            20.0000 |            67.8357 |      1.0000 |
# 0.353127
#    80 | 06m44s |    0.35313 |             0.2000 |           5.0000 |      3.0000 |            12.0768 |           244.6760 |      1.0000 |
# 0.372598
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.0001417]), 'nit': 5, 'warnflag': 2, 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 55}
#   " state: %s" % convergence_dict)
#    81 | 07m34s |    0.37260 |             0.2000 |           5.0000 |      3.0000 |             1.0000 |            90.3120 |      1.0000 |
# 0.348969
#    82 | 07m05s |    0.34897 |             0.2000 |           0.0000 |      3.0000 |            20.0000 |           109.5990 |      1.0000 |
# 0.379371
#    83 | 08m39s |    0.37937 |             0.2000 |           5.0000 |      3.0000 |             9.7517 |            38.3198 |      1.0000 |
# 0.362526
#    84 | 08m24s |    0.36253 |             0.2000 |           5.0000 |      3.0000 |             1.0000 |           226.3575 |      1.0000 |
# 0.299195
#    85 | 10m51s |    0.29919 |             1.0000 |           5.0000 |      3.0000 |            20.0000 |           211.6033 |      0.2000 |
# 0.423078
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ -4.70752658e-05]), 'nit': 5, 'warnflag': 2, 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 53}
#   " state: %s" % convergence_dict)
#    86 | 11m22s |    0.42308 |             0.2000 |           5.0000 |     15.0000 |             1.0000 |             1.0000 |      1.0000 |
# 0.318358
#    87 | 26m49s |    0.31836 |             1.0000 |           0.0000 |     15.0000 |            20.0000 |           198.3610 |      1.0000 |
# 0.372002
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ -3.02766377e-05]), 'nit': 5, 'warnflag': 2, 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 53}
#   " state: %s" % convergence_dict)
#    88 | 07m59s |    0.37200 |             0.2000 |           5.0000 |      3.0000 |            20.0000 |            76.4704 |      1.0000 |
# 0.356115
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.00018459]), 'nit': 3, 'warnflag': 2, 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 49}
#   " state: %s" % convergence_dict)
#    89 | 07m21s |    0.35612 |             0.2000 |           0.0000 |      3.0000 |            10.3742 |            85.3764 |      1.0000 |
# 0.381446
#    90 | 08m26s |    0.38145 |             0.2000 |           5.0000 |     15.0000 |            20.0000 |           135.2744 |      1.0000 |
# 0.365731
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ -5.79985679e-05]), 'nit': 6, 'warnflag': 2, 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 54}
#   " state: %s" % convergence_dict)
#    91 | 08m03s |    0.36573 |             0.2000 |           5.0000 |     15.0000 |             6.3224 |            78.2617 |      1.0000 |
# 0.39059
#    92 | 17m58s |    0.39059 |             0.6927 |           4.3848 |     13.0850 |             1.1535 |            19.4403 |      0.9962 |
# 0.414411
#    93 | 09m41s |    0.41441 |             0.2000 |           4.7324 |     12.8505 |            19.7865 |            25.2757 |      1.0000 |
# 0.325443
#    94 | 07m56s |    0.32544 |             0.2000 |           5.0000 |      3.0000 |             6.8586 |           290.0771 |      1.0000 |
# 0.353636
#    95 | 07m45s |    0.35364 |             0.2000 |           5.0000 |      3.0000 |             9.3526 |           136.2803 |      1.0000 |
# 0.358905
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ -3.41872333e-05]), 'nit': 5, 'warnflag': 2, 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 56}
#   " state: %s" % convergence_dict)
#    96 | 07m17s |    0.35890 |             0.2000 |           5.0000 |      3.0000 |            10.2179 |           159.1801 |      1.0000 |
# 0.357194
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([  7.82476117e-05]), 'nit': 5, 'warnflag': 2, 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 53}
#   " state: %s" % convergence_dict)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.00017346]), 'nit': 4, 'warnflag': 2, 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 52}
#   " state: %s" % convergence_dict)
#    97 | 09m41s |    0.35719 |             0.2000 |           5.0000 |     15.0000 |            20.0000 |           242.2731 |      1.0000 |
# 0.256376
#    98 | 09m11s |    0.25638 |             0.2000 |           5.0000 |     15.0000 |             1.0000 |           197.5829 |      1.0000 |
# 0.347831
#    99 | 08m46s |    0.34783 |             0.2000 |           5.0000 |     15.0000 |            20.0000 |           175.4436 |      1.0000 |
# 0.417176
#   100 | 11m57s |    0.41718 |             0.3125 |           0.0000 |     15.0000 |            13.2131 |            45.2288 |      1.0000 |
# 0.365703
#   101 | 07m27s |    0.36570 |             0.2000 |           5.0000 |      3.0000 |             9.7114 |           113.9215 |      1.0000 |
# 0.387782
#   102 | 17m25s |    0.38778 |             1.0000 |           0.0000 |      8.7088 |            10.4478 |            32.6172 |      1.0000 |
# 0.346309
#   103 | 13m06s |    0.34631 |             0.4658 |           0.0023 |      3.0000 |             1.0000 |            33.0666 |      1.0000 |
# 0.378082
#   104 | 07m29s |    0.37808 |             0.2000 |           5.0000 |      3.0000 |            20.0000 |            10.7263 |      1.0000 |
# 0.337054
#   105 | 06m17s |    0.33705 |             0.2000 |           0.0000 |      3.0000 |             1.0000 |           180.2305 |      1.0000 |
#
# Final Results
# XGBOOST: 0.474122
